# %%
# !pip install opencv-python==4.8.1.78
# Out:
# Requirement already satisfied: opencv-python==4.8.1.78 in c:\programdata\anaconda3\envs\tensorflow_gpu_env01\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\programdata\anaconda3\envs\tensorflow_gpu_env01\lib\site-packages (from opencv-python==4.8.1.78) (1.26.4)

# %%
import cv2
import matplotlib.pyplot as plt
import dlib

# %%
cap = cv2.VideoCapture(0)

# %%
detector = dlib.get_frontal_face_detector()

# %%
while cap.isOpened() == True:
    success, image = cap.read()

    if success == False:
        continue

    faces = detector(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    for face in faces:
        print("얼굴 찾음!!")
        print("얼굴 위치=", face)
        print("="*100)

    cv2.imshow('webcam_window01', image)
    key = cv2.waitKey(1)

    if key == ord('q'):
        #image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #plt.imsave('cam_img.jpg', image_rgb)
        break
# Out:
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(148, 162) (272, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 148) (286, 272)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 148) (300, 272)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 148) (300, 272)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 162) (300, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 162) (300, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 162) (300, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 162) (300, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(162, 162) (286, 286)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(161, 145) (311, 294)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(161, 145) (311, 294)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(161, 145) (311, 294)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(161, 145) (311, 294)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(161, 145) (311, 294)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 148) (300, 272)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 148) (300, 272)]
# ====================================================================================================
# 얼굴 찾음!!
# 얼굴 위치= [(176, 148) (300, 272)]
# ====================================================================================================

# %%
cap.release()
cv2.destroyAllWindows()
