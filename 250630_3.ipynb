# %%
import numpy as np
import torch

# %%
X = np.array([160, 170, 180, 190])
X
# Out:
# array([160, 170, 180, 190])

# %%
y = np.array([0, 0, 1, 1])
y
# Out:
# array([0, 0, 1, 1])

# %%
a = 0.1
b = -17

# %%
def sigmoid(z):
    return 1 / (1 + torch.exp(-z))

# %%
learning_rate = 0.1
epochs = 1000

# %%
X_mean = np.mean(X)
X_mean
# Out:
# 175.0

# %%
X_std = np.std(X)
X_std
# Out:
# 11.180339887498949

# %%
X_norm = (X - X_mean) / X_std
print("정규화된 입력값 X_mean:", X_norm)
# Out:
# 정규화된 입력값 X_mean: [-1.34164079 -0.4472136   0.4472136   1.34164079]

# %%
a = torch.tensor([0.1], requires_grad=True)
b = torch.tensor([-17.0], requires_grad=True)

# %%
X_tensor = torch.tensor(X_norm, dtype=torch.float32)
X_tensor
# Out:
# tensor([-1.3416, -0.4472,  0.4472,  1.3416])

# %%
y_tensor = torch.tensor(y, dtype=torch.float32)
y_tensor
# Out:
# tensor([0., 0., 1., 1.])

# %%
for epoch in range(epochs):
    z = a * X_tensor + b
    H = sigmoid(z)

    costs = -(y_tensor * torch.log(H) + (1 - y_tensor) * torch.log(1 - H)).mean()
    costs.backward()

    with torch.no_grad():
        a -= learning_rate * a.grad
        b -= learning_rate * b.grad

    a.grad.zero_()
    b.grad.zero_()

    print(f"Epoch {epoch}, 평균 비용: {costs}, a: {a}, b: {b}")
# Out:
# Epoch 0, 평균 비용: 8.455278396606445, a: tensor([0.1447], requires_grad=True), b: tensor([-16.9500], requires_grad=True)
# Epoch 1, 평균 비용: 8.4102783203125, a: tensor([0.1894], requires_grad=True), b: tensor([-16.9000], requires_grad=True)
# Epoch 2, 평균 비용: 8.365280151367188, a: tensor([0.2342], requires_grad=True), b: tensor([-16.8500], requires_grad=True)
# Epoch 3, 평균 비용: 8.320280075073242, a: tensor([0.2789], requires_grad=True), b: tensor([-16.8000], requires_grad=True)
# Epoch 4, 평균 비용: 8.275279998779297, a: tensor([0.3236], requires_grad=True), b: tensor([-16.7500], requires_grad=True)
# Epoch 5, 평균 비용: 8.230279922485352, a: tensor([0.3683], requires_grad=True), b: tensor([-16.7000], requires_grad=True)
# Epoch 6, 평균 비용: 8.185281753540039, a: tensor([0.4130], requires_grad=True), b: tensor([-16.6500], requires_grad=True)
# Epoch 7, 평균 비용: 8.140281677246094, a: tensor([0.4578], requires_grad=True), b: tensor([-16.6000], requires_grad=True)
# Epoch 8, 평균 비용: 8.095281600952148, a: tensor([0.5025], requires_grad=True), b: tensor([-16.5500], requires_grad=True)
# Epoch 9, 평균 비용: 8.050281524658203, a: tensor([0.5472], requires_grad=True), b: tensor([-16.5000], requires_grad=True)
# Epoch 10, 평균 비용: 8.005282402038574, a: tensor([0.5919], requires_grad=True), b: tensor([-16.4500], requires_grad=True)
# Epoch 11, 평균 비용: 7.960283279418945, a: tensor([0.6367], requires_grad=True), b: tensor([-16.4000], requires_grad=True)
# Epoch 12, 평균 비용: 7.915283203125, a: tensor([0.6814], requires_grad=True), b: tensor([-16.3500], requires_grad=True)
# Epoch 13, 평균 비용: 7.870283126831055, a: tensor([0.7261], requires_grad=True), b: tensor([-16.3000], requires_grad=True)
# Epoch 14, 평균 비용: 7.825284004211426, a: tensor([0.7708], requires_grad=True), b: tensor([-16.2500], requires_grad=True)
# Epoch 15, 평균 비용: 7.7802839279174805, a: tensor([0.8155], requires_grad=True), b: tensor([-16.2000], requires_grad=True)
# Epoch 16, 평균 비용: 7.735284805297852, a: tensor([0.8603], requires_grad=True), b: tensor([-16.1500], requires_grad=True)
# Epoch 17, 평균 비용: 7.690284729003906, a: tensor([0.9050], requires_grad=True), b: tensor([-16.1000], requires_grad=True)
# Epoch 18, 평균 비용: 7.645285606384277, a: tensor([0.9497], requires_grad=True), b: tensor([-16.0500], requires_grad=True)
# Epoch 19, 평균 비용: 7.600285530090332, a: tensor([0.9944], requires_grad=True), b: tensor([-16.0000], requires_grad=True)
# Epoch 20, 평균 비용: 7.555286407470703, a: tensor([1.0391], requires_grad=True), b: tensor([-15.9500], requires_grad=True)
# Epoch 21, 평균 비용: 7.510286331176758, a: tensor([1.0839], requires_grad=True), b: tensor([-15.9000], requires_grad=True)
# Epoch 22, 평균 비용: 7.4652862548828125, a: tensor([1.1286], requires_grad=True), b: tensor([-15.8500], requires_grad=True)
# Epoch 23, 평균 비용: 7.420286178588867, a: tensor([1.1733], requires_grad=True), b: tensor([-15.8000], requires_grad=True)
# Epoch 24, 평균 비용: 7.375286102294922, a: tensor([1.2180], requires_grad=True), b: tensor([-15.7500], requires_grad=True)
# Epoch 25, 평균 비용: 7.330286026000977, a: tensor([1.2628], requires_grad=True), b: tensor([-15.7000], requires_grad=True)
# Epoch 26, 평균 비용: 7.285285949707031, a: tensor([1.3075], requires_grad=True), b: tensor([-15.6500], requires_grad=True)
# Epoch 27, 평균 비용: 7.240285873413086, a: tensor([1.3522], requires_grad=True), b: tensor([-15.6000], requires_grad=True)
# Epoch 28, 평균 비용: 7.195285797119141, a: tensor([1.3969], requires_grad=True), b: tensor([-15.5500], requires_grad=True)
# Epoch 29, 평균 비용: 7.150285720825195, a: tensor([1.4416], requires_grad=True), b: tensor([-15.5000], requires_grad=True)
# Epoch 30, 평균 비용: 7.10528564453125, a: tensor([1.4864], requires_grad=True), b: tensor([-15.4500], requires_grad=True)
# Epoch 31, 평균 비용: 7.060285568237305, a: tensor([1.5311], requires_grad=True), b: tensor([-15.4000], requires_grad=True)
# Epoch 32, 평균 비용: 7.015285491943359, a: tensor([1.5758], requires_grad=True), b: tensor([-15.3500], requires_grad=True)
# Epoch 33, 평균 비용: 6.970285415649414, a: tensor([1.6205], requires_grad=True), b: tensor([-15.3000], requires_grad=True)
# Epoch 34, 평균 비용: 6.925285816192627, a: tensor([1.6652], requires_grad=True), b: tensor([-15.2500], requires_grad=True)
# Epoch 35, 평균 비용: 6.880285263061523, a: tensor([1.7100], requires_grad=True), b: tensor([-15.2000], requires_grad=True)
# Epoch 36, 평균 비용: 6.8352861404418945, a: tensor([1.7547], requires_grad=True), b: tensor([-15.1500], requires_grad=True)
# Epoch 37, 평균 비용: 6.790286064147949, a: tensor([1.7994], requires_grad=True), b: tensor([-15.1000], requires_grad=True)
# Epoch 38, 평균 비용: 6.745285987854004, a: tensor([1.8441], requires_grad=True), b: tensor([-15.0500], requires_grad=True)
# Epoch 39, 평균 비용: 6.700285911560059, a: tensor([1.8889], requires_grad=True), b: tensor([-15.0000], requires_grad=True)
# Epoch 40, 평균 비용: 6.655285835266113, a: tensor([1.9336], requires_grad=True), b: tensor([-14.9500], requires_grad=True)
# Epoch 41, 평균 비용: 6.610285758972168, a: tensor([1.9783], requires_grad=True), b: tensor([-14.9000], requires_grad=True)
# Epoch 42, 평균 비용: 6.565285682678223, a: tensor([2.0230], requires_grad=True), b: tensor([-14.8500], requires_grad=True)
# Epoch 43, 평균 비용: 6.5202860832214355, a: tensor([2.0677], requires_grad=True), b: tensor([-14.8000], requires_grad=True)
# Epoch 44, 평균 비용: 6.475286483764648, a: tensor([2.1125], requires_grad=True), b: tensor([-14.7500], requires_grad=True)
# Epoch 45, 평균 비용: 6.430286407470703, a: tensor([2.1572], requires_grad=True), b: tensor([-14.7000], requires_grad=True)
# Epoch 46, 평균 비용: 6.385286331176758, a: tensor([2.2019], requires_grad=True), b: tensor([-14.6500], requires_grad=True)
# Epoch 47, 평균 비용: 6.340287208557129, a: tensor([2.2466], requires_grad=True), b: tensor([-14.6000], requires_grad=True)
# Epoch 48, 평균 비용: 6.295287132263184, a: tensor([2.2913], requires_grad=True), b: tensor([-14.5500], requires_grad=True)
# Epoch 49, 평균 비용: 6.2502875328063965, a: tensor([2.3361], requires_grad=True), b: tensor([-14.5000], requires_grad=True)
# Epoch 50, 평균 비용: 6.205288410186768, a: tensor([2.3808], requires_grad=True), b: tensor([-14.4500], requires_grad=True)
# Epoch 51, 평균 비용: 6.160289764404297, a: tensor([2.4255], requires_grad=True), b: tensor([-14.4000], requires_grad=True)
# Epoch 52, 평균 비용: 6.115290641784668, a: tensor([2.4702], requires_grad=True), b: tensor([-14.3500], requires_grad=True)
# Epoch 53, 평균 비용: 6.070291519165039, a: tensor([2.5149], requires_grad=True), b: tensor([-14.3000], requires_grad=True)
# Epoch 54, 평균 비용: 6.02529239654541, a: tensor([2.5597], requires_grad=True), b: tensor([-14.2500], requires_grad=True)
# Epoch 55, 평균 비용: 5.980293273925781, a: tensor([2.6044], requires_grad=True), b: tensor([-14.2000], requires_grad=True)
# Epoch 56, 평균 비용: 5.935295104980469, a: tensor([2.6491], requires_grad=True), b: tensor([-14.1500], requires_grad=True)
# Epoch 57, 평균 비용: 5.890296459197998, a: tensor([2.6938], requires_grad=True), b: tensor([-14.1000], requires_grad=True)
# Epoch 58, 평균 비용: 5.845297813415527, a: tensor([2.7386], requires_grad=True), b: tensor([-14.0500], requires_grad=True)
# Epoch 59, 평균 비용: 5.800299644470215, a: tensor([2.7833], requires_grad=True), b: tensor([-14.0000], requires_grad=True)
# Epoch 60, 평균 비용: 5.755301475524902, a: tensor([2.8280], requires_grad=True), b: tensor([-13.9500], requires_grad=True)
# Epoch 61, 평균 비용: 5.71030330657959, a: tensor([2.8727], requires_grad=True), b: tensor([-13.9000], requires_grad=True)
# Epoch 62, 평균 비용: 5.665305137634277, a: tensor([2.9174], requires_grad=True), b: tensor([-13.8500], requires_grad=True)
# Epoch 63, 평균 비용: 5.620307922363281, a: tensor([2.9622], requires_grad=True), b: tensor([-13.8000], requires_grad=True)
# Epoch 64, 평균 비용: 5.575310707092285, a: tensor([3.0069], requires_grad=True), b: tensor([-13.7500], requires_grad=True)
# Epoch 65, 평균 비용: 5.5303144454956055, a: tensor([3.0516], requires_grad=True), b: tensor([-13.7000], requires_grad=True)
# Epoch 66, 평균 비용: 5.485318183898926, a: tensor([3.0963], requires_grad=True), b: tensor([-13.6500], requires_grad=True)
# Epoch 67, 평균 비용: 5.440321922302246, a: tensor([3.1410], requires_grad=True), b: tensor([-13.6000], requires_grad=True)
# Epoch 68, 평균 비용: 5.395326137542725, a: tensor([3.1857], requires_grad=True), b: tensor([-13.5500], requires_grad=True)
# Epoch 69, 평균 비용: 5.3503313064575195, a: tensor([3.2305], requires_grad=True), b: tensor([-13.5000], requires_grad=True)
# Epoch 70, 평균 비용: 5.305336952209473, a: tensor([3.2752], requires_grad=True), b: tensor([-13.4500], requires_grad=True)
# Epoch 71, 평균 비용: 5.260342597961426, a: tensor([3.3199], requires_grad=True), b: tensor([-13.4000], requires_grad=True)
# Epoch 72, 평균 비용: 5.215350151062012, a: tensor([3.3646], requires_grad=True), b: tensor([-13.3500], requires_grad=True)
# Epoch 73, 평균 비용: 5.170356750488281, a: tensor([3.4093], requires_grad=True), b: tensor([-13.3000], requires_grad=True)
# Epoch 74, 평균 비용: 5.125365734100342, a: tensor([3.4540], requires_grad=True), b: tensor([-13.2501], requires_grad=True)
# Epoch 75, 평균 비용: 5.080375671386719, a: tensor([3.4988], requires_grad=True), b: tensor([-13.2001], requires_grad=True)
# Epoch 76, 평균 비용: 5.035386085510254, a: tensor([3.5435], requires_grad=True), b: tensor([-13.1501], requires_grad=True)
# Epoch 77, 평균 비용: 4.990397930145264, a: tensor([3.5882], requires_grad=True), b: tensor([-13.1001], requires_grad=True)
# Epoch 78, 평균 비용: 4.94541072845459, a: tensor([3.6329], requires_grad=True), b: tensor([-13.0501], requires_grad=True)
# Epoch 79, 평균 비용: 4.900424957275391, a: tensor([3.6776], requires_grad=True), b: tensor([-13.0001], requires_grad=True)
# Epoch 80, 평균 비용: 4.855441570281982, a: tensor([3.7223], requires_grad=True), b: tensor([-12.9501], requires_grad=True)
# Epoch 81, 평균 비용: 4.810460090637207, a: tensor([3.7670], requires_grad=True), b: tensor([-12.9001], requires_grad=True)
# Epoch 82, 평균 비용: 4.7654805183410645, a: tensor([3.8117], requires_grad=True), b: tensor([-12.8501], requires_grad=True)
# Epoch 83, 평균 비용: 4.720503330230713, a: tensor([3.8565], requires_grad=True), b: tensor([-12.8001], requires_grad=True)
# Epoch 84, 평균 비용: 4.675528526306152, a: tensor([3.9012], requires_grad=True), b: tensor([-12.7501], requires_grad=True)
# Epoch 85, 평균 비용: 4.630556583404541, a: tensor([3.9459], requires_grad=True), b: tensor([-12.7001], requires_grad=True)
# Epoch 86, 평균 비용: 4.585587978363037, a: tensor([3.9906], requires_grad=True), b: tensor([-12.6502], requires_grad=True)
# Epoch 87, 평균 비용: 4.540622711181641, a: tensor([4.0353], requires_grad=True), b: tensor([-12.6002], requires_grad=True)
# Epoch 88, 평균 비용: 4.495661735534668, a: tensor([4.0800], requires_grad=True), b: tensor([-12.5502], requires_grad=True)
# Epoch 89, 평균 비용: 4.450705528259277, a: tensor([4.1246], requires_grad=True), b: tensor([-12.5002], requires_grad=True)
# Epoch 90, 평균 비용: 4.405754089355469, a: tensor([4.1693], requires_grad=True), b: tensor([-12.4502], requires_grad=True)
# Epoch 91, 평균 비용: 4.3608078956604, a: tensor([4.2140], requires_grad=True), b: tensor([-12.4003], requires_grad=True)
# Epoch 92, 평균 비용: 4.315868377685547, a: tensor([4.2587], requires_grad=True), b: tensor([-12.3503], requires_grad=True)
# Epoch 93, 평균 비용: 4.270935535430908, a: tensor([4.3034], requires_grad=True), b: tensor([-12.3003], requires_grad=True)
# Epoch 94, 평균 비용: 4.226010799407959, a: tensor([4.3481], requires_grad=True), b: tensor([-12.2504], requires_grad=True)
# Epoch 95, 평균 비용: 4.181094169616699, a: tensor([4.3927], requires_grad=True), b: tensor([-12.2004], requires_grad=True)
# Epoch 96, 평균 비용: 4.13618803024292, a: tensor([4.4374], requires_grad=True), b: tensor([-12.1505], requires_grad=True)
# Epoch 97, 평균 비용: 4.091291904449463, a: tensor([4.4820], requires_grad=True), b: tensor([-12.1005], requires_grad=True)
# Epoch 98, 평균 비용: 4.046407699584961, a: tensor([4.5267], requires_grad=True), b: tensor([-12.0506], requires_grad=True)
# Epoch 99, 평균 비용: 4.001537322998047, a: tensor([4.5713], requires_grad=True), b: tensor([-12.0006], requires_grad=True)
# Epoch 100, 평균 비용: 3.9566822052001953, a: tensor([4.6159], requires_grad=True), b: tensor([-11.9507], requires_grad=True)
# Epoch 101, 평균 비용: 3.9118430614471436, a: tensor([4.6606], requires_grad=True), b: tensor([-11.9008], requires_grad=True)
# Epoch 102, 평균 비용: 3.867022752761841, a: tensor([4.7052], requires_grad=True), b: tensor([-11.8509], requires_grad=True)
# Epoch 103, 평균 비용: 3.82222318649292, a: tensor([4.7497], requires_grad=True), b: tensor([-11.8010], requires_grad=True)
# Epoch 104, 평균 비용: 3.7774462699890137, a: tensor([4.7943], requires_grad=True), b: tensor([-11.7511], requires_grad=True)
# Epoch 105, 평균 비용: 3.7326953411102295, a: tensor([4.8389], requires_grad=True), b: tensor([-11.7012], requires_grad=True)
# Epoch 106, 평균 비용: 3.6879730224609375, a: tensor([4.8834], requires_grad=True), b: tensor([-11.6513], requires_grad=True)
# Epoch 107, 평균 비용: 3.643282651901245, a: tensor([4.9279], requires_grad=True), b: tensor([-11.6015], requires_grad=True)
# Epoch 108, 평균 비용: 3.5986275672912598, a: tensor([4.9724], requires_grad=True), b: tensor([-11.5517], requires_grad=True)
# Epoch 109, 평균 비용: 3.5540120601654053, a: tensor([5.0169], requires_grad=True), b: tensor([-11.5019], requires_grad=True)
# Epoch 110, 평균 비용: 3.5094404220581055, a: tensor([5.0613], requires_grad=True), b: tensor([-11.4521], requires_grad=True)
# Epoch 111, 평균 비용: 3.4649176597595215, a: tensor([5.1057], requires_grad=True), b: tensor([-11.4023], requires_grad=True)
# Epoch 112, 평균 비용: 3.4204487800598145, a: tensor([5.1501], requires_grad=True), b: tensor([-11.3526], requires_grad=True)
# Epoch 113, 평균 비용: 3.3760406970977783, a: tensor([5.1944], requires_grad=True), b: tensor([-11.3029], requires_grad=True)
# Epoch 114, 평균 비용: 3.3316996097564697, a: tensor([5.2387], requires_grad=True), b: tensor([-11.2532], requires_grad=True)
# Epoch 115, 평균 비용: 3.28743314743042, a: tensor([5.2830], requires_grad=True), b: tensor([-11.2036], requires_grad=True)
# Epoch 116, 평균 비용: 3.2432491779327393, a: tensor([5.3271], requires_grad=True), b: tensor([-11.1540], requires_grad=True)
# Epoch 117, 평균 비용: 3.199157238006592, a: tensor([5.3713], requires_grad=True), b: tensor([-11.1044], requires_grad=True)
# Epoch 118, 평균 비용: 3.1551663875579834, a: tensor([5.4153], requires_grad=True), b: tensor([-11.0549], requires_grad=True)
# Epoch 119, 평균 비용: 3.1112890243530273, a: tensor([5.4593], requires_grad=True), b: tensor([-11.0055], requires_grad=True)
# Epoch 120, 평균 비용: 3.067535161972046, a: tensor([5.5032], requires_grad=True), b: tensor([-10.9561], requires_grad=True)
# Epoch 121, 평균 비용: 3.0239200592041016, a: tensor([5.5470], requires_grad=True), b: tensor([-10.9068], requires_grad=True)
# Epoch 122, 평균 비용: 2.980456590652466, a: tensor([5.5907], requires_grad=True), b: tensor([-10.8575], requires_grad=True)
# Epoch 123, 평균 비용: 2.9371604919433594, a: tensor([5.6343], requires_grad=True), b: tensor([-10.8084], requires_grad=True)
# Epoch 124, 평균 비용: 2.8940491676330566, a: tensor([5.6777], requires_grad=True), b: tensor([-10.7593], requires_grad=True)
# Epoch 125, 평균 비용: 2.851141929626465, a: tensor([5.7211], requires_grad=True), b: tensor([-10.7104], requires_grad=True)
# Epoch 126, 평균 비용: 2.808457851409912, a: tensor([5.7643], requires_grad=True), b: tensor([-10.6615], requires_grad=True)
# Epoch 127, 평균 비용: 2.766019105911255, a: tensor([5.8073], requires_grad=True), b: tensor([-10.6128], requires_grad=True)
# Epoch 128, 평균 비용: 2.723848342895508, a: tensor([5.8501], requires_grad=True), b: tensor([-10.5642], requires_grad=True)
# Epoch 129, 평균 비용: 2.6819708347320557, a: tensor([5.8927], requires_grad=True), b: tensor([-10.5158], requires_grad=True)
# Epoch 130, 평균 비용: 2.640413284301758, a: tensor([5.9352], requires_grad=True), b: tensor([-10.4675], requires_grad=True)
# Epoch 131, 평균 비용: 2.599203109741211, a: tensor([5.9773], requires_grad=True), b: tensor([-10.4194], requires_grad=True)
# Epoch 132, 평균 비용: 2.5583701133728027, a: tensor([6.0193], requires_grad=True), b: tensor([-10.3715], requires_grad=True)
# Epoch 133, 평균 비용: 2.517944812774658, a: tensor([6.0609], requires_grad=True), b: tensor([-10.3238], requires_grad=True)
# Epoch 134, 평균 비용: 2.477959394454956, a: tensor([6.1023], requires_grad=True), b: tensor([-10.2763], requires_grad=True)
# Epoch 135, 평균 비용: 2.4384469985961914, a: tensor([6.1433], requires_grad=True), b: tensor([-10.2291], requires_grad=True)
# Epoch 136, 평균 비용: 2.3994414806365967, a: tensor([6.1840], requires_grad=True), b: tensor([-10.1821], requires_grad=True)
# Epoch 137, 평균 비용: 2.3609776496887207, a: tensor([6.2243], requires_grad=True), b: tensor([-10.1354], requires_grad=True)
# Epoch 138, 평균 비용: 2.323089361190796, a: tensor([6.2641], requires_grad=True), b: tensor([-10.0890], requires_grad=True)
# Epoch 139, 평균 비용: 2.285810947418213, a: tensor([6.3036], requires_grad=True), b: tensor([-10.0430], requires_grad=True)
# Epoch 140, 평균 비용: 2.249175786972046, a: tensor([6.3426], requires_grad=True), b: tensor([-9.9972], requires_grad=True)
# Epoch 141, 평균 비용: 2.2132155895233154, a: tensor([6.3812], requires_grad=True), b: tensor([-9.9518], requires_grad=True)
# Epoch 142, 평균 비용: 2.177961587905884, a: tensor([6.4192], requires_grad=True), b: tensor([-9.9069], requires_grad=True)
# Epoch 143, 평균 비용: 2.143441915512085, a: tensor([6.4567], requires_grad=True), b: tensor([-9.8623], requires_grad=True)
# Epoch 144, 평균 비용: 2.109682083129883, a: tensor([6.4936], requires_grad=True), b: tensor([-9.8181], requires_grad=True)
# Epoch 145, 평균 비용: 2.0767054557800293, a: tensor([6.5300], requires_grad=True), b: tensor([-9.7743], requires_grad=True)
# Epoch 146, 평균 비용: 2.0445315837860107, a: tensor([6.5658], requires_grad=True), b: tensor([-9.7310], requires_grad=True)
# Epoch 147, 평균 비용: 2.013176202774048, a: tensor([6.6009], requires_grad=True), b: tensor([-9.6881], requires_grad=True)
# Epoch 148, 평균 비용: 1.9826509952545166, a: tensor([6.6355], requires_grad=True), b: tensor([-9.6457], requires_grad=True)
# Epoch 149, 평균 비용: 1.9529640674591064, a: tensor([6.6694], requires_grad=True), b: tensor([-9.6038], requires_grad=True)
# Epoch 150, 평균 비용: 1.924118995666504, a: tensor([6.7026], requires_grad=True), b: tensor([-9.5624], requires_grad=True)
# Epoch 151, 평균 비용: 1.8961153030395508, a: tensor([6.7352], requires_grad=True), b: tensor([-9.5215], requires_grad=True)
# Epoch 152, 평균 비용: 1.8689485788345337, a: tensor([6.7671], requires_grad=True), b: tensor([-9.4810], requires_grad=True)
# Epoch 153, 평균 비용: 1.8426110744476318, a: tensor([6.7984], requires_grad=True), b: tensor([-9.4411], requires_grad=True)
# Epoch 154, 평균 비용: 1.8170905113220215, a: tensor([6.8290], requires_grad=True), b: tensor([-9.4017], requires_grad=True)
# Epoch 155, 평균 비용: 1.792372703552246, a: tensor([6.8589], requires_grad=True), b: tensor([-9.3627], requires_grad=True)
# Epoch 156, 평균 비용: 1.7684398889541626, a: tensor([6.8882], requires_grad=True), b: tensor([-9.3242], requires_grad=True)
# Epoch 157, 평균 비용: 1.7452714443206787, a: tensor([6.9168], requires_grad=True), b: tensor([-9.2863], requires_grad=True)
# Epoch 158, 평균 비용: 1.722845435142517, a: tensor([6.9448], requires_grad=True), b: tensor([-9.2488], requires_grad=True)
# Epoch 159, 평균 비용: 1.7011380195617676, a: tensor([6.9722], requires_grad=True), b: tensor([-9.2118], requires_grad=True)
# Epoch 160, 평균 비용: 1.6801236867904663, a: tensor([6.9989], requires_grad=True), b: tensor([-9.1752], requires_grad=True)
# Epoch 161, 평균 비용: 1.6597775220870972, a: tensor([7.0250], requires_grad=True), b: tensor([-9.1391], requires_grad=True)
# Epoch 162, 평균 비용: 1.6400713920593262, a: tensor([7.0506], requires_grad=True), b: tensor([-9.1035], requires_grad=True)
# Epoch 163, 평균 비용: 1.6209790706634521, a: tensor([7.0755], requires_grad=True), b: tensor([-9.0682], requires_grad=True)
# Epoch 164, 평균 비용: 1.602473497390747, a: tensor([7.0999], requires_grad=True), b: tensor([-9.0334], requires_grad=True)
# Epoch 165, 평균 비용: 1.584527850151062, a: tensor([7.1238], requires_grad=True), b: tensor([-8.9990], requires_grad=True)
# Epoch 166, 평균 비용: 1.5671155452728271, a: tensor([7.1472], requires_grad=True), b: tensor([-8.9650], requires_grad=True)
# Epoch 167, 평균 비용: 1.550210952758789, a: tensor([7.1700], requires_grad=True), b: tensor([-8.9313], requires_grad=True)
# Epoch 168, 평균 비용: 1.5337891578674316, a: tensor([7.1924], requires_grad=True), b: tensor([-8.8980], requires_grad=True)
# Epoch 169, 평균 비용: 1.5178256034851074, a: tensor([7.2143], requires_grad=True), b: tensor([-8.8651], requires_grad=True)
# Epoch 170, 평균 비용: 1.5022965669631958, a: tensor([7.2357], requires_grad=True), b: tensor([-8.8325], requires_grad=True)
# Epoch 171, 평균 비용: 1.4871798753738403, a: tensor([7.2567], requires_grad=True), b: tensor([-8.8003], requires_grad=True)
# Epoch 172, 평균 비용: 1.4724539518356323, a: tensor([7.2773], requires_grad=True), b: tensor([-8.7683], requires_grad=True)
# Epoch 173, 평균 비용: 1.4580981731414795, a: tensor([7.2975], requires_grad=True), b: tensor([-8.7367], requires_grad=True)
# Epoch 174, 평균 비용: 1.4440925121307373, a: tensor([7.3173], requires_grad=True), b: tensor([-8.7053], requires_grad=True)
# Epoch 175, 평균 비용: 1.430418848991394, a: tensor([7.3367], requires_grad=True), b: tensor([-8.6742], requires_grad=True)
# Epoch 176, 평균 비용: 1.4170589447021484, a: tensor([7.3558], requires_grad=True), b: tensor([-8.6434], requires_grad=True)
# Epoch 177, 평균 비용: 1.4039965867996216, a: tensor([7.3745], requires_grad=True), b: tensor([-8.6129], requires_grad=True)
# Epoch 178, 평균 비용: 1.3912153244018555, a: tensor([7.3930], requires_grad=True), b: tensor([-8.5826], requires_grad=True)
# Epoch 179, 평균 비용: 1.378700613975525, a: tensor([7.4111], requires_grad=True), b: tensor([-8.5525], requires_grad=True)
# Epoch 180, 평균 비용: 1.3664382696151733, a: tensor([7.4289], requires_grad=True), b: tensor([-8.5226], requires_grad=True)
# Epoch 181, 평균 비용: 1.354414463043213, a: tensor([7.4464], requires_grad=True), b: tensor([-8.4930], requires_grad=True)
# Epoch 182, 평균 비용: 1.342617154121399, a: tensor([7.4636], requires_grad=True), b: tensor([-8.4636], requires_grad=True)
# Epoch 183, 평균 비용: 1.3310340642929077, a: tensor([7.4806], requires_grad=True), b: tensor([-8.4343], requires_grad=True)
# Epoch 184, 평균 비용: 1.3196542263031006, a: tensor([7.4974], requires_grad=True), b: tensor([-8.4053], requires_grad=True)
# Epoch 185, 평균 비용: 1.3084667921066284, a: tensor([7.5139], requires_grad=True), b: tensor([-8.3764], requires_grad=True)
# Epoch 186, 평균 비용: 1.2974622249603271, a: tensor([7.5301], requires_grad=True), b: tensor([-8.3478], requires_grad=True)
# Epoch 187, 평균 비용: 1.2866312265396118, a: tensor([7.5462], requires_grad=True), b: tensor([-8.3192], requires_grad=True)
# Epoch 188, 평균 비용: 1.2759647369384766, a: tensor([7.5620], requires_grad=True), b: tensor([-8.2909], requires_grad=True)
# Epoch 189, 평균 비용: 1.265454649925232, a: tensor([7.5777], requires_grad=True), b: tensor([-8.2627], requires_grad=True)
# Epoch 190, 평균 비용: 1.255092978477478, a: tensor([7.5931], requires_grad=True), b: tensor([-8.2346], requires_grad=True)
# Epoch 191, 평균 비용: 1.2448724508285522, a: tensor([7.6084], requires_grad=True), b: tensor([-8.2067], requires_grad=True)
# Epoch 192, 평균 비용: 1.2347862720489502, a: tensor([7.6234], requires_grad=True), b: tensor([-8.1790], requires_grad=True)
# Epoch 193, 평균 비용: 1.2248282432556152, a: tensor([7.6384], requires_grad=True), b: tensor([-8.1513], requires_grad=True)
# Epoch 194, 평균 비용: 1.214991569519043, a: tensor([7.6531], requires_grad=True), b: tensor([-8.1238], requires_grad=True)
# Epoch 195, 평균 비용: 1.2052706480026245, a: tensor([7.6677], requires_grad=True), b: tensor([-8.0964], requires_grad=True)
# Epoch 196, 평균 비용: 1.1956604719161987, a: tensor([7.6822], requires_grad=True), b: tensor([-8.0691], requires_grad=True)
# Epoch 197, 평균 비용: 1.1861557960510254, a: tensor([7.6965], requires_grad=True), b: tensor([-8.0419], requires_grad=True)
# Epoch 198, 평균 비용: 1.1767514944076538, a: tensor([7.7106], requires_grad=True), b: tensor([-8.0149], requires_grad=True)
# Epoch 199, 평균 비용: 1.1674431562423706, a: tensor([7.7247], requires_grad=True), b: tensor([-7.9879], requires_grad=True)
# Epoch 200, 평균 비용: 1.158226490020752, a: tensor([7.7386], requires_grad=True), b: tensor([-7.9611], requires_grad=True)
# Epoch 201, 평균 비용: 1.1490974426269531, a: tensor([7.7524], requires_grad=True), b: tensor([-7.9343], requires_grad=True)
# Epoch 202, 평균 비용: 1.140052318572998, a: tensor([7.7661], requires_grad=True), b: tensor([-7.9076], requires_grad=True)
# Epoch 203, 평균 비용: 1.131087064743042, a: tensor([7.7796], requires_grad=True), b: tensor([-7.8810], requires_grad=True)
# Epoch 204, 평균 비용: 1.1221988201141357, a: tensor([7.7931], requires_grad=True), b: tensor([-7.8545], requires_grad=True)
# Epoch 205, 평균 비용: 1.1133843660354614, a: tensor([7.8065], requires_grad=True), b: tensor([-7.8281], requires_grad=True)
# Epoch 206, 평균 비용: 1.1046403646469116, a: tensor([7.8197], requires_grad=True), b: tensor([-7.8018], requires_grad=True)
# Epoch 207, 평균 비용: 1.0959640741348267, a: tensor([7.8329], requires_grad=True), b: tensor([-7.7755], requires_grad=True)
# Epoch 208, 평균 비용: 1.0873527526855469, a: tensor([7.8459], requires_grad=True), b: tensor([-7.7494], requires_grad=True)
# Epoch 209, 평균 비용: 1.0788040161132812, a: tensor([7.8589], requires_grad=True), b: tensor([-7.7233], requires_grad=True)
# Epoch 210, 평균 비용: 1.0703152418136597, a: tensor([7.8718], requires_grad=True), b: tensor([-7.6972], requires_grad=True)
# Epoch 211, 평균 비용: 1.0618842840194702, a: tensor([7.8847], requires_grad=True), b: tensor([-7.6712], requires_grad=True)
# Epoch 212, 평균 비용: 1.05350923538208, a: tensor([7.8974], requires_grad=True), b: tensor([-7.6453], requires_grad=True)
# Epoch 213, 평균 비용: 1.0451877117156982, a: tensor([7.9101], requires_grad=True), b: tensor([-7.6195], requires_grad=True)
# Epoch 214, 평균 비용: 1.0369181632995605, a: tensor([7.9227], requires_grad=True), b: tensor([-7.5937], requires_grad=True)
# Epoch 215, 평균 비용: 1.028698444366455, a: tensor([7.9352], requires_grad=True), b: tensor([-7.5680], requires_grad=True)
# Epoch 216, 평균 비용: 1.0205271244049072, a: tensor([7.9477], requires_grad=True), b: tensor([-7.5423], requires_grad=True)
# Epoch 217, 평균 비용: 1.0124026536941528, a: tensor([7.9600], requires_grad=True), b: tensor([-7.5167], requires_grad=True)
# Epoch 218, 평균 비용: 1.0043230056762695, a: tensor([7.9724], requires_grad=True), b: tensor([-7.4912], requires_grad=True)
# Epoch 219, 평균 비용: 0.9962873458862305, a: tensor([7.9847], requires_grad=True), b: tensor([-7.4657], requires_grad=True)
# Epoch 220, 평균 비용: 0.9882941246032715, a: tensor([7.9969], requires_grad=True), b: tensor([-7.4403], requires_grad=True)
# Epoch 221, 평균 비용: 0.9803421497344971, a: tensor([8.0090], requires_grad=True), b: tensor([-7.4149], requires_grad=True)
# Epoch 222, 평균 비용: 0.9724302291870117, a: tensor([8.0211], requires_grad=True), b: tensor([-7.3895], requires_grad=True)
# Epoch 223, 평균 비용: 0.9645572900772095, a: tensor([8.0332], requires_grad=True), b: tensor([-7.3643], requires_grad=True)
# Epoch 224, 평균 비용: 0.9567221403121948, a: tensor([8.0452], requires_grad=True), b: tensor([-7.3390], requires_grad=True)
# Epoch 225, 평균 비용: 0.9489241242408752, a: tensor([8.0571], requires_grad=True), b: tensor([-7.3138], requires_grad=True)
# Epoch 226, 평균 비용: 0.9411619305610657, a: tensor([8.0690], requires_grad=True), b: tensor([-7.2887], requires_grad=True)
# Epoch 227, 평균 비용: 0.9334349632263184, a: tensor([8.0809], requires_grad=True), b: tensor([-7.2636], requires_grad=True)
# Epoch 228, 평균 비용: 0.9257423877716064, a: tensor([8.0927], requires_grad=True), b: tensor([-7.2386], requires_grad=True)
# Epoch 229, 평균 비용: 0.9180836081504822, a: tensor([8.1045], requires_grad=True), b: tensor([-7.2136], requires_grad=True)
# Epoch 230, 평균 비용: 0.9104578495025635, a: tensor([8.1162], requires_grad=True), b: tensor([-7.1886], requires_grad=True)
# Epoch 231, 평균 비용: 0.9028644561767578, a: tensor([8.1279], requires_grad=True), b: tensor([-7.1637], requires_grad=True)
# Epoch 232, 평균 비용: 0.8953028321266174, a: tensor([8.1395], requires_grad=True), b: tensor([-7.1388], requires_grad=True)
# Epoch 233, 평균 비용: 0.8877723813056946, a: tensor([8.1511], requires_grad=True), b: tensor([-7.1140], requires_grad=True)
# Epoch 234, 평균 비용: 0.8802727460861206, a: tensor([8.1627], requires_grad=True), b: tensor([-7.0892], requires_grad=True)
# Epoch 235, 평균 비용: 0.8728033304214478, a: tensor([8.1742], requires_grad=True), b: tensor([-7.0645], requires_grad=True)
# Epoch 236, 평균 비용: 0.8653639554977417, a: tensor([8.1857], requires_grad=True), b: tensor([-7.0398], requires_grad=True)
# Epoch 237, 평균 비용: 0.8579539060592651, a: tensor([8.1971], requires_grad=True), b: tensor([-7.0152], requires_grad=True)
# Epoch 238, 평균 비용: 0.8505730032920837, a: tensor([8.2085], requires_grad=True), b: tensor([-6.9905], requires_grad=True)
# Epoch 239, 평균 비용: 0.8432210683822632, a: tensor([8.2199], requires_grad=True), b: tensor([-6.9660], requires_grad=True)
# Epoch 240, 평균 비용: 0.8358978033065796, a: tensor([8.2313], requires_grad=True), b: tensor([-6.9415], requires_grad=True)
# Epoch 241, 평균 비용: 0.8286030292510986, a: tensor([8.2426], requires_grad=True), b: tensor([-6.9170], requires_grad=True)
# Epoch 242, 평균 비용: 0.8213363289833069, a: tensor([8.2538], requires_grad=True), b: tensor([-6.8925], requires_grad=True)
# Epoch 243, 평균 비용: 0.8140978217124939, a: tensor([8.2651], requires_grad=True), b: tensor([-6.8681], requires_grad=True)
# Epoch 244, 평균 비용: 0.8068870902061462, a: tensor([8.2763], requires_grad=True), b: tensor([-6.8438], requires_grad=True)
# Epoch 245, 평균 비용: 0.7997041940689087, a: tensor([8.2875], requires_grad=True), b: tensor([-6.8195], requires_grad=True)
# Epoch 246, 평균 비용: 0.7925490140914917, a: tensor([8.2987], requires_grad=True), b: tensor([-6.7952], requires_grad=True)
# Epoch 247, 평균 비용: 0.7854213714599609, a: tensor([8.3098], requires_grad=True), b: tensor([-6.7710], requires_grad=True)
# Epoch 248, 평균 비용: 0.778321385383606, a: tensor([8.3209], requires_grad=True), b: tensor([-6.7468], requires_grad=True)
# Epoch 249, 평균 비용: 0.7712491154670715, a: tensor([8.3319], requires_grad=True), b: tensor([-6.7226], requires_grad=True)
# Epoch 250, 평균 비용: 0.7642045617103577, a: tensor([8.3430], requires_grad=True), b: tensor([-6.6985], requires_grad=True)
# Epoch 251, 평균 비용: 0.75718754529953, a: tensor([8.3540], requires_grad=True), b: tensor([-6.6745], requires_grad=True)
# Epoch 252, 평균 비용: 0.7501983642578125, a: tensor([8.3649], requires_grad=True), b: tensor([-6.6505], requires_grad=True)
# Epoch 253, 평균 비용: 0.7432370781898499, a: tensor([8.3759], requires_grad=True), b: tensor([-6.6265], requires_grad=True)
# Epoch 254, 평균 비용: 0.7363036870956421, a: tensor([8.3868], requires_grad=True), b: tensor([-6.6026], requires_grad=True)
# Epoch 255, 평균 비용: 0.7293984293937683, a: tensor([8.3977], requires_grad=True), b: tensor([-6.5787], requires_grad=True)
# Epoch 256, 평균 비용: 0.7225215435028076, a: tensor([8.4086], requires_grad=True), b: tensor([-6.5549], requires_grad=True)
# Epoch 257, 평균 비용: 0.7156729698181152, a: tensor([8.4194], requires_grad=True), b: tensor([-6.5311], requires_grad=True)
# Epoch 258, 평균 비용: 0.7088531851768494, a: tensor([8.4302], requires_grad=True), b: tensor([-6.5074], requires_grad=True)
# Epoch 259, 평균 비용: 0.7020620107650757, a: tensor([8.4410], requires_grad=True), b: tensor([-6.4837], requires_grad=True)
# Epoch 260, 평균 비용: 0.6952999234199524, a: tensor([8.4517], requires_grad=True), b: tensor([-6.4601], requires_grad=True)
# Epoch 261, 평균 비용: 0.6885672807693481, a: tensor([8.4624], requires_grad=True), b: tensor([-6.4365], requires_grad=True)
# Epoch 262, 평균 비용: 0.6818641424179077, a: tensor([8.4731], requires_grad=True), b: tensor([-6.4130], requires_grad=True)
# Epoch 263, 평균 비용: 0.6751906871795654, a: tensor([8.4838], requires_grad=True), b: tensor([-6.3895], requires_grad=True)
# Epoch 264, 평균 비용: 0.6685473918914795, a: tensor([8.4944], requires_grad=True), b: tensor([-6.3661], requires_grad=True)
# Epoch 265, 평균 비용: 0.661934494972229, a: tensor([8.5050], requires_grad=True), b: tensor([-6.3427], requires_grad=True)
# Epoch 266, 평균 비용: 0.6553522348403931, a: tensor([8.5156], requires_grad=True), b: tensor([-6.3193], requires_grad=True)
# Epoch 267, 평균 비용: 0.6488010883331299, a: tensor([8.5261], requires_grad=True), b: tensor([-6.2961], requires_grad=True)
# Epoch 268, 평균 비용: 0.6422811150550842, a: tensor([8.5366], requires_grad=True), b: tensor([-6.2729], requires_grad=True)
# Epoch 269, 평균 비용: 0.6357930302619934, a: tensor([8.5471], requires_grad=True), b: tensor([-6.2497], requires_grad=True)
# Epoch 270, 평균 비용: 0.6293368339538574, a: tensor([8.5576], requires_grad=True), b: tensor([-6.2266], requires_grad=True)
# Epoch 271, 평균 비용: 0.6229131817817688, a: tensor([8.5680], requires_grad=True), b: tensor([-6.2035], requires_grad=True)
# Epoch 272, 평균 비용: 0.6165222525596619, a: tensor([8.5784], requires_grad=True), b: tensor([-6.1805], requires_grad=True)
# Epoch 273, 평균 비용: 0.6101645231246948, a: tensor([8.5888], requires_grad=True), b: tensor([-6.1576], requires_grad=True)
# Epoch 274, 평균 비용: 0.6038404107093811, a: tensor([8.5991], requires_grad=True), b: tensor([-6.1347], requires_grad=True)
# Epoch 275, 평균 비용: 0.5975501537322998, a: tensor([8.6094], requires_grad=True), b: tensor([-6.1119], requires_grad=True)
# Epoch 276, 평균 비용: 0.5912943482398987, a: tensor([8.6197], requires_grad=True), b: tensor([-6.0892], requires_grad=True)
# Epoch 277, 평균 비용: 0.5850732326507568, a: tensor([8.6299], requires_grad=True), b: tensor([-6.0665], requires_grad=True)
# Epoch 278, 평균 비용: 0.5788872241973877, a: tensor([8.6401], requires_grad=True), b: tensor([-6.0439], requires_grad=True)
# Epoch 279, 평균 비용: 0.5727368593215942, a: tensor([8.6503], requires_grad=True), b: tensor([-6.0213], requires_grad=True)
# Epoch 280, 평균 비용: 0.5666225552558899, a: tensor([8.6604], requires_grad=True), b: tensor([-5.9988], requires_grad=True)
# Epoch 281, 평균 비용: 0.5605447292327881, a: tensor([8.6705], requires_grad=True), b: tensor([-5.9764], requires_grad=True)
# Epoch 282, 평균 비용: 0.5545036792755127, a: tensor([8.6806], requires_grad=True), b: tensor([-5.9541], requires_grad=True)
# Epoch 283, 평균 비용: 0.5484999418258667, a: tensor([8.6907], requires_grad=True), b: tensor([-5.9318], requires_grad=True)
# Epoch 284, 평균 비용: 0.5425340533256531, a: tensor([8.7007], requires_grad=True), b: tensor([-5.9096], requires_grad=True)
# Epoch 285, 평균 비용: 0.5366062521934509, a: tensor([8.7106], requires_grad=True), b: tensor([-5.8874], requires_grad=True)
# Epoch 286, 평균 비용: 0.5307170152664185, a: tensor([8.7206], requires_grad=True), b: tensor([-5.8653], requires_grad=True)
# Epoch 287, 평균 비용: 0.5248667001724243, a: tensor([8.7305], requires_grad=True), b: tensor([-5.8433], requires_grad=True)
# Epoch 288, 평균 비용: 0.5190559029579163, a: tensor([8.7404], requires_grad=True), b: tensor([-5.8214], requires_grad=True)
# Epoch 289, 평균 비용: 0.5132848620414734, a: tensor([8.7502], requires_grad=True), b: tensor([-5.7996], requires_grad=True)
# Epoch 290, 평균 비용: 0.5075541138648987, a: tensor([8.7600], requires_grad=True), b: tensor([-5.7778], requires_grad=True)
# Epoch 291, 평균 비용: 0.5018641352653503, a: tensor([8.7697], requires_grad=True), b: tensor([-5.7561], requires_grad=True)
# Epoch 292, 평균 비용: 0.496215283870697, a: tensor([8.7795], requires_grad=True), b: tensor([-5.7345], requires_grad=True)
# Epoch 293, 평균 비용: 0.490607887506485, a: tensor([8.7892], requires_grad=True), b: tensor([-5.7129], requires_grad=True)
# Epoch 294, 평균 비용: 0.4850422739982605, a: tensor([8.7988], requires_grad=True), b: tensor([-5.6915], requires_grad=True)
# Epoch 295, 평균 비용: 0.47951894998550415, a: tensor([8.8084], requires_grad=True), b: tensor([-5.6701], requires_grad=True)
# Epoch 296, 평균 비용: 0.47403833270072937, a: tensor([8.8180], requires_grad=True), b: tensor([-5.6488], requires_grad=True)
# Epoch 297, 평균 비용: 0.46860072016716003, a: tensor([8.8275], requires_grad=True), b: tensor([-5.6276], requires_grad=True)
# Epoch 298, 평균 비용: 0.4632064998149872, a: tensor([8.8370], requires_grad=True), b: tensor([-5.6065], requires_grad=True)
# Epoch 299, 평균 비용: 0.45785602927207947, a: tensor([8.8465], requires_grad=True), b: tensor([-5.5855], requires_grad=True)
# Epoch 300, 평균 비용: 0.4525497257709503, a: tensor([8.8559], requires_grad=True), b: tensor([-5.5645], requires_grad=True)
# Epoch 301, 평균 비용: 0.4472877085208893, a: tensor([8.8652], requires_grad=True), b: tensor([-5.5437], requires_grad=True)
# Epoch 302, 평균 비용: 0.44207054376602173, a: tensor([8.8746], requires_grad=True), b: tensor([-5.5229], requires_grad=True)
# Epoch 303, 평균 비용: 0.436898410320282, a: tensor([8.8839], requires_grad=True), b: tensor([-5.5022], requires_grad=True)
# Epoch 304, 평균 비용: 0.4317716956138611, a: tensor([8.8931], requires_grad=True), b: tensor([-5.4816], requires_grad=True)
# Epoch 305, 평균 비용: 0.42669060826301575, a: tensor([8.9023], requires_grad=True), b: tensor([-5.4611], requires_grad=True)
# Epoch 306, 평균 비용: 0.42165544629096985, a: tensor([8.9115], requires_grad=True), b: tensor([-5.4407], requires_grad=True)
# Epoch 307, 평균 비용: 0.41666653752326965, a: tensor([8.9206], requires_grad=True), b: tensor([-5.4204], requires_grad=True)
# Epoch 308, 평균 비용: 0.4117240011692047, a: tensor([8.9296], requires_grad=True), b: tensor([-5.4002], requires_grad=True)
# Epoch 309, 평균 비용: 0.4068281054496765, a: tensor([8.9387], requires_grad=True), b: tensor([-5.3801], requires_grad=True)
# Epoch 310, 평균 비용: 0.40197908878326416, a: tensor([8.9477], requires_grad=True), b: tensor([-5.3601], requires_grad=True)
# Epoch 311, 평균 비용: 0.397177129983902, a: tensor([8.9566], requires_grad=True), b: tensor([-5.3402], requires_grad=True)
# Epoch 312, 평균 비용: 0.39242255687713623, a: tensor([8.9655], requires_grad=True), b: tensor([-5.3203], requires_grad=True)
# Epoch 313, 평균 비용: 0.387715220451355, a: tensor([8.9743], requires_grad=True), b: tensor([-5.3006], requires_grad=True)
# Epoch 314, 평균 비용: 0.3830556273460388, a: tensor([8.9831], requires_grad=True), b: tensor([-5.2810], requires_grad=True)
# Epoch 315, 평균 비용: 0.37844371795654297, a: tensor([8.9919], requires_grad=True), b: tensor([-5.2615], requires_grad=True)
# Epoch 316, 평균 비용: 0.3738795816898346, a: tensor([9.0006], requires_grad=True), b: tensor([-5.2421], requires_grad=True)
# Epoch 317, 평균 비용: 0.3693634569644928, a: tensor([9.0093], requires_grad=True), b: tensor([-5.2228], requires_grad=True)
# Epoch 318, 평균 비용: 0.3648953437805176, a: tensor([9.0179], requires_grad=True), b: tensor([-5.2036], requires_grad=True)
# Epoch 319, 평균 비용: 0.36047524213790894, a: tensor([9.0265], requires_grad=True), b: tensor([-5.1845], requires_grad=True)
# Epoch 320, 평균 비용: 0.3561032712459564, a: tensor([9.0350], requires_grad=True), b: tensor([-5.1655], requires_grad=True)
# Epoch 321, 평균 비용: 0.351779580116272, a: tensor([9.0435], requires_grad=True), b: tensor([-5.1466], requires_grad=True)
# Epoch 322, 평균 비용: 0.3475039601325989, a: tensor([9.0519], requires_grad=True), b: tensor([-5.1278], requires_grad=True)
# Epoch 323, 평균 비용: 0.34327661991119385, a: tensor([9.0603], requires_grad=True), b: tensor([-5.1091], requires_grad=True)
# Epoch 324, 평균 비용: 0.33909741044044495, a: tensor([9.0686], requires_grad=True), b: tensor([-5.0905], requires_grad=True)
# Epoch 325, 평균 비용: 0.3349662721157074, a: tensor([9.0769], requires_grad=True), b: tensor([-5.0721], requires_grad=True)
# Epoch 326, 평균 비용: 0.33088329434394836, a: tensor([9.0851], requires_grad=True), b: tensor([-5.0537], requires_grad=True)
# Epoch 327, 평균 비용: 0.32684823870658875, a: tensor([9.0933], requires_grad=True), b: tensor([-5.0354], requires_grad=True)
# Epoch 328, 평균 비용: 0.322860985994339, a: tensor([9.1014], requires_grad=True), b: tensor([-5.0173], requires_grad=True)
# Epoch 329, 평균 비용: 0.31892162561416626, a: tensor([9.1095], requires_grad=True), b: tensor([-4.9993], requires_grad=True)
# Epoch 330, 평균 비용: 0.31502994894981384, a: tensor([9.1175], requires_grad=True), b: tensor([-4.9814], requires_grad=True)
# Epoch 331, 평균 비용: 0.31118568778038025, a: tensor([9.1255], requires_grad=True), b: tensor([-4.9636], requires_grad=True)
# Epoch 332, 평균 비용: 0.30738893151283264, a: tensor([9.1334], requires_grad=True), b: tensor([-4.9459], requires_grad=True)
# Epoch 333, 평균 비용: 0.3036392629146576, a: tensor([9.1413], requires_grad=True), b: tensor([-4.9283], requires_grad=True)
# Epoch 334, 평균 비용: 0.2999366819858551, a: tensor([9.1491], requires_grad=True), b: tensor([-4.9108], requires_grad=True)
# Epoch 335, 평균 비용: 0.2962808907032013, a: tensor([9.1569], requires_grad=True), b: tensor([-4.8934], requires_grad=True)
# Epoch 336, 평균 비용: 0.29267174005508423, a: tensor([9.1647], requires_grad=True), b: tensor([-4.8762], requires_grad=True)
# Epoch 337, 평균 비용: 0.28910893201828003, a: tensor([9.1723], requires_grad=True), b: tensor([-4.8590], requires_grad=True)
# Epoch 338, 평균 비용: 0.2855921983718872, a: tensor([9.1800], requires_grad=True), b: tensor([-4.8420], requires_grad=True)
# Epoch 339, 평균 비용: 0.2821213901042938, a: tensor([9.1876], requires_grad=True), b: tensor([-4.8251], requires_grad=True)
# Epoch 340, 평균 비용: 0.27869611978530884, a: tensor([9.1951], requires_grad=True), b: tensor([-4.8083], requires_grad=True)
# Epoch 341, 평균 비용: 0.27531611919403076, a: tensor([9.2026], requires_grad=True), b: tensor([-4.7916], requires_grad=True)
# Epoch 342, 평균 비용: 0.2719811201095581, a: tensor([9.2100], requires_grad=True), b: tensor([-4.7750], requires_grad=True)
# Epoch 343, 평균 비용: 0.2686907649040222, a: tensor([9.2174], requires_grad=True), b: tensor([-4.7585], requires_grad=True)
# Epoch 344, 평균 비용: 0.265444815158844, a: tensor([9.2247], requires_grad=True), b: tensor([-4.7422], requires_grad=True)
# Epoch 345, 평균 비용: 0.2622429430484772, a: tensor([9.2320], requires_grad=True), b: tensor([-4.7259], requires_grad=True)
# Epoch 346, 평균 비용: 0.25908464193344116, a: tensor([9.2392], requires_grad=True), b: tensor([-4.7098], requires_grad=True)
# Epoch 347, 평균 비용: 0.25596991181373596, a: tensor([9.2464], requires_grad=True), b: tensor([-4.6938], requires_grad=True)
# Epoch 348, 평균 비용: 0.2528979480266571, a: tensor([9.2535], requires_grad=True), b: tensor([-4.6779], requires_grad=True)
# Epoch 349, 평균 비용: 0.24986867606639862, a: tensor([9.2606], requires_grad=True), b: tensor([-4.6621], requires_grad=True)
# Epoch 350, 평균 비용: 0.24688169360160828, a: tensor([9.2676], requires_grad=True), b: tensor([-4.6464], requires_grad=True)
# Epoch 351, 평균 비용: 0.24393650889396667, a: tensor([9.2746], requires_grad=True), b: tensor([-4.6308], requires_grad=True)
# Epoch 352, 평균 비용: 0.24103283882141113, a: tensor([9.2815], requires_grad=True), b: tensor([-4.6153], requires_grad=True)
# Epoch 353, 평균 비용: 0.23817011713981628, a: tensor([9.2884], requires_grad=True), b: tensor([-4.6000], requires_grad=True)
# Epoch 354, 평균 비용: 0.2353481650352478, a: tensor([9.2953], requires_grad=True), b: tensor([-4.5847], requires_grad=True)
# Epoch 355, 평균 비용: 0.23256638646125793, a: tensor([9.3020], requires_grad=True), b: tensor([-4.5696], requires_grad=True)
# Epoch 356, 평균 비용: 0.22982440888881683, a: tensor([9.3088], requires_grad=True), b: tensor([-4.5546], requires_grad=True)
# Epoch 357, 평균 비용: 0.22712184488773346, a: tensor([9.3155], requires_grad=True), b: tensor([-4.5396], requires_grad=True)
# Epoch 358, 평균 비용: 0.22445830702781677, a: tensor([9.3221], requires_grad=True), b: tensor([-4.5248], requires_grad=True)
# Epoch 359, 평균 비용: 0.22183328866958618, a: tensor([9.3287], requires_grad=True), b: tensor([-4.5101], requires_grad=True)
# Epoch 360, 평균 비용: 0.2192462831735611, a: tensor([9.3352], requires_grad=True), b: tensor([-4.4955], requires_grad=True)
# Epoch 361, 평균 비용: 0.21669700741767883, a: tensor([9.3417], requires_grad=True), b: tensor([-4.4810], requires_grad=True)
# Epoch 362, 평균 비용: 0.2141849398612976, a: tensor([9.3482], requires_grad=True), b: tensor([-4.4666], requires_grad=True)
# Epoch 363, 평균 비용: 0.21170958876609802, a: tensor([9.3545], requires_grad=True), b: tensor([-4.4524], requires_grad=True)
# Epoch 364, 평균 비용: 0.20927055180072784, a: tensor([9.3609], requires_grad=True), b: tensor([-4.4382], requires_grad=True)
# Epoch 365, 평균 비용: 0.20686745643615723, a: tensor([9.3672], requires_grad=True), b: tensor([-4.4241], requires_grad=True)
# Epoch 366, 평균 비용: 0.20449966192245483, a: tensor([9.3735], requires_grad=True), b: tensor([-4.4102], requires_grad=True)
# Epoch 367, 평균 비용: 0.2021668404340744, a: tensor([9.3797], requires_grad=True), b: tensor([-4.3963], requires_grad=True)
# Epoch 368, 평균 비용: 0.1998685896396637, a: tensor([9.3858], requires_grad=True), b: tensor([-4.3825], requires_grad=True)
# Epoch 369, 평균 비용: 0.19760438799858093, a: tensor([9.3919], requires_grad=True), b: tensor([-4.3689], requires_grad=True)
# Epoch 370, 평균 비용: 0.1953738033771515, a: tensor([9.3980], requires_grad=True), b: tensor([-4.3553], requires_grad=True)
# Epoch 371, 평균 비용: 0.19317631423473358, a: tensor([9.4040], requires_grad=True), b: tensor([-4.3419], requires_grad=True)
# Epoch 372, 평균 비용: 0.19101163744926453, a: tensor([9.4100], requires_grad=True), b: tensor([-4.3285], requires_grad=True)
# Epoch 373, 평균 비용: 0.18887916207313538, a: tensor([9.4160], requires_grad=True), b: tensor([-4.3153], requires_grad=True)
# Epoch 374, 평균 비용: 0.18677851557731628, a: tensor([9.4219], requires_grad=True), b: tensor([-4.3021], requires_grad=True)
# Epoch 375, 평균 비용: 0.18470923602581024, a: tensor([9.4277], requires_grad=True), b: tensor([-4.2891], requires_grad=True)
# Epoch 376, 평균 비용: 0.18267083168029785, a: tensor([9.4335], requires_grad=True), b: tensor([-4.2761], requires_grad=True)
# Epoch 377, 평균 비용: 0.18066297471523285, a: tensor([9.4393], requires_grad=True), b: tensor([-4.2633], requires_grad=True)
# Epoch 378, 평균 비용: 0.17868509888648987, a: tensor([9.4450], requires_grad=True), b: tensor([-4.2505], requires_grad=True)
# Epoch 379, 평균 비용: 0.17673689126968384, a: tensor([9.4507], requires_grad=True), b: tensor([-4.2378], requires_grad=True)
# Epoch 380, 평균 비용: 0.17481786012649536, a: tensor([9.4563], requires_grad=True), b: tensor([-4.2253], requires_grad=True)
# Epoch 381, 평균 비용: 0.17292743921279907, a: tensor([9.4619], requires_grad=True), b: tensor([-4.2128], requires_grad=True)
# Epoch 382, 평균 비용: 0.17106541991233826, a: tensor([9.4674], requires_grad=True), b: tensor([-4.2004], requires_grad=True)
# Epoch 383, 평균 비용: 0.16923123598098755, a: tensor([9.4729], requires_grad=True), b: tensor([-4.1881], requires_grad=True)
# Epoch 384, 평균 비용: 0.16742448508739471, a: tensor([9.4784], requires_grad=True), b: tensor([-4.1759], requires_grad=True)
# Epoch 385, 평균 비용: 0.1656447798013687, a: tensor([9.4838], requires_grad=True), b: tensor([-4.1638], requires_grad=True)
# Epoch 386, 평균 비용: 0.1638917326927185, a: tensor([9.4892], requires_grad=True), b: tensor([-4.1518], requires_grad=True)
# Epoch 387, 평균 비용: 0.1621648371219635, a: tensor([9.4945], requires_grad=True), b: tensor([-4.1399], requires_grad=True)
# Epoch 388, 평균 비용: 0.16046375036239624, a: tensor([9.4998], requires_grad=True), b: tensor([-4.1280], requires_grad=True)
# Epoch 389, 평균 비용: 0.15878812968730927, a: tensor([9.5051], requires_grad=True), b: tensor([-4.1163], requires_grad=True)
# Epoch 390, 평균 비용: 0.15713746845722198, a: tensor([9.5103], requires_grad=True), b: tensor([-4.1046], requires_grad=True)
# Epoch 391, 평균 비용: 0.15551140904426575, a: tensor([9.5155], requires_grad=True), b: tensor([-4.0930], requires_grad=True)
# Epoch 392, 평균 비용: 0.1539095938205719, a: tensor([9.5207], requires_grad=True), b: tensor([-4.0816], requires_grad=True)
# Epoch 393, 평균 비용: 0.15233150124549866, a: tensor([9.5258], requires_grad=True), b: tensor([-4.0702], requires_grad=True)
# Epoch 394, 평균 비용: 0.1507769674062729, a: tensor([9.5308], requires_grad=True), b: tensor([-4.0588], requires_grad=True)
# Epoch 395, 평균 비용: 0.149245485663414, a: tensor([9.5359], requires_grad=True), b: tensor([-4.0476], requires_grad=True)
# Epoch 396, 평균 비용: 0.14773671329021454, a: tensor([9.5409], requires_grad=True), b: tensor([-4.0365], requires_grad=True)
# Epoch 397, 평균 비용: 0.14625026285648346, a: tensor([9.5458], requires_grad=True), b: tensor([-4.0254], requires_grad=True)
# Epoch 398, 평균 비용: 0.14478570222854614, a: tensor([9.5507], requires_grad=True), b: tensor([-4.0144], requires_grad=True)
# Epoch 399, 평균 비용: 0.1433427482843399, a: tensor([9.5556], requires_grad=True), b: tensor([-4.0035], requires_grad=True)
# ...
# Epoch 870, 평균 비용: 0.018718264997005463, a: tensor([10.4206], requires_grad=True), b: tensor([-2.0874], requires_grad=True)
# Epoch 871, 평균 비용: 0.018681231886148453, a: tensor([10.4214], requires_grad=True), b: tensor([-2.0857], requires_grad=True)
# Epoch 872, 평균 비용: 0.01864439807832241, a: tensor([10.4223], requires_grad=True), b: tensor([-2.0839], requires_grad=True)
# Epoch 873, 평균 비용: 0.01860767975449562, a: tensor([10.4231], requires_grad=True), b: tensor([-2.0822], requires_grad=True)
# Epoch 874, 평균 비용: 0.018571127206087112, a: tensor([10.4239], requires_grad=True), b: tensor([-2.0804], requires_grad=True)
# Epoch 875, 평균 비용: 0.01853470876812935, a: tensor([10.4247], requires_grad=True), b: tensor([-2.0787], requires_grad=True)
# Epoch 876, 평균 비용: 0.01849842444062233, a: tensor([10.4255], requires_grad=True), b: tensor([-2.0770], requires_grad=True)
# Epoch 877, 평균 비용: 0.018462276086211205, a: tensor([10.4263], requires_grad=True), b: tensor([-2.0753], requires_grad=True)
# Epoch 878, 평균 비용: 0.018426289781928062, a: tensor([10.4270], requires_grad=True), b: tensor([-2.0735], requires_grad=True)
# Epoch 879, 평균 비용: 0.018390437588095665, a: tensor([10.4278], requires_grad=True), b: tensor([-2.0718], requires_grad=True)
# Epoch 880, 평균 비용: 0.018354736268520355, a: tensor([10.4286], requires_grad=True), b: tensor([-2.0701], requires_grad=True)
# Epoch 881, 평균 비용: 0.018319150432944298, a: tensor([10.4294], requires_grad=True), b: tensor([-2.0684], requires_grad=True)
# Epoch 882, 평균 비용: 0.018283730372786522, a: tensor([10.4302], requires_grad=True), b: tensor([-2.0667], requires_grad=True)
# Epoch 883, 평균 비용: 0.018248429521918297, a: tensor([10.4310], requires_grad=True), b: tensor([-2.0650], requires_grad=True)
# Epoch 884, 평균 비용: 0.01821327582001686, a: tensor([10.4318], requires_grad=True), b: tensor([-2.0633], requires_grad=True)
# Epoch 885, 평균 비용: 0.018178239464759827, a: tensor([10.4326], requires_grad=True), b: tensor([-2.0616], requires_grad=True)
# Epoch 886, 평균 비용: 0.018143383786082268, a: tensor([10.4334], requires_grad=True), b: tensor([-2.0599], requires_grad=True)
# Epoch 887, 평균 비용: 0.01810864545404911, a: tensor([10.4341], requires_grad=True), b: tensor([-2.0582], requires_grad=True)
# Epoch 888, 평균 비용: 0.018074024468660355, a: tensor([10.4349], requires_grad=True), b: tensor([-2.0565], requires_grad=True)
# Epoch 889, 평균 비용: 0.01803956739604473, a: tensor([10.4357], requires_grad=True), b: tensor([-2.0549], requires_grad=True)
# Epoch 890, 평균 비용: 0.01800518110394478, a: tensor([10.4365], requires_grad=True), b: tensor([-2.0532], requires_grad=True)
# Epoch 891, 평균 비용: 0.017970973625779152, a: tensor([10.4373], requires_grad=True), b: tensor([-2.0515], requires_grad=True)
# Epoch 892, 평균 비용: 0.017936885356903076, a: tensor([10.4380], requires_grad=True), b: tensor([-2.0498], requires_grad=True)
# Epoch 893, 평균 비용: 0.01790294423699379, a: tensor([10.4388], requires_grad=True), b: tensor([-2.0482], requires_grad=True)
# Epoch 894, 평균 비용: 0.01786913350224495, a: tensor([10.4396], requires_grad=True), b: tensor([-2.0465], requires_grad=True)
# Epoch 895, 평균 비용: 0.01783544197678566, a: tensor([10.4403], requires_grad=True), b: tensor([-2.0448], requires_grad=True)
# Epoch 896, 평균 비용: 0.01780189946293831, a: tensor([10.4411], requires_grad=True), b: tensor([-2.0432], requires_grad=True)
# Epoch 897, 평균 비용: 0.017768409103155136, a: tensor([10.4419], requires_grad=True), b: tensor([-2.0415], requires_grad=True)
# Epoch 898, 평균 비용: 0.017735114321112633, a: tensor([10.4427], requires_grad=True), b: tensor([-2.0399], requires_grad=True)
# Epoch 899, 평균 비용: 0.017701953649520874, a: tensor([10.4434], requires_grad=True), b: tensor([-2.0382], requires_grad=True)
# Epoch 900, 평균 비용: 0.01766890659928322, a: tensor([10.4442], requires_grad=True), b: tensor([-2.0366], requires_grad=True)
# Epoch 901, 평균 비용: 0.01763596013188362, a: tensor([10.4449], requires_grad=True), b: tensor([-2.0349], requires_grad=True)
# Epoch 902, 평균 비용: 0.01760314591228962, a: tensor([10.4457], requires_grad=True), b: tensor([-2.0333], requires_grad=True)
# Epoch 903, 평균 비용: 0.017570465803146362, a: tensor([10.4465], requires_grad=True), b: tensor([-2.0316], requires_grad=True)
# Epoch 904, 평균 비용: 0.017537886276841164, a: tensor([10.4472], requires_grad=True), b: tensor([-2.0300], requires_grad=True)
# Epoch 905, 평균 비용: 0.017505452036857605, a: tensor([10.4480], requires_grad=True), b: tensor([-2.0284], requires_grad=True)
# Epoch 906, 평균 비용: 0.017473135143518448, a: tensor([10.4487], requires_grad=True), b: tensor([-2.0267], requires_grad=True)
# Epoch 907, 평균 비용: 0.017440950497984886, a: tensor([10.4495], requires_grad=True), b: tensor([-2.0251], requires_grad=True)
# Epoch 908, 평균 비용: 0.017408881336450577, a: tensor([10.4502], requires_grad=True), b: tensor([-2.0235], requires_grad=True)
# Epoch 909, 평균 비용: 0.017376942560076714, a: tensor([10.4510], requires_grad=True), b: tensor([-2.0219], requires_grad=True)
# Epoch 910, 평균 비용: 0.01734510436654091, a: tensor([10.4517], requires_grad=True), b: tensor([-2.0203], requires_grad=True)
# Epoch 911, 평균 비용: 0.017313338816165924, a: tensor([10.4525], requires_grad=True), b: tensor([-2.0187], requires_grad=True)
# Epoch 912, 평균 비용: 0.017281780019402504, a: tensor([10.4532], requires_grad=True), b: tensor([-2.0170], requires_grad=True)
# Epoch 913, 평균 비용: 0.017250273376703262, a: tensor([10.4540], requires_grad=True), b: tensor([-2.0154], requires_grad=True)
# Epoch 914, 평균 비용: 0.01721891574561596, a: tensor([10.4547], requires_grad=True), b: tensor([-2.0138], requires_grad=True)
# Epoch 915, 평균 비용: 0.01718767359852791, a: tensor([10.4555], requires_grad=True), b: tensor([-2.0122], requires_grad=True)
# Epoch 916, 평균 비용: 0.017156530171632767, a: tensor([10.4562], requires_grad=True), b: tensor([-2.0106], requires_grad=True)
# Epoch 917, 평균 비용: 0.017125532031059265, a: tensor([10.4570], requires_grad=True), b: tensor([-2.0090], requires_grad=True)
# Epoch 918, 평균 비용: 0.01709458976984024, a: tensor([10.4577], requires_grad=True), b: tensor([-2.0074], requires_grad=True)
# Epoch 919, 평균 비용: 0.017063794657588005, a: tensor([10.4584], requires_grad=True), b: tensor([-2.0059], requires_grad=True)
# Epoch 920, 평균 비용: 0.017033113166689873, a: tensor([10.4592], requires_grad=True), b: tensor([-2.0043], requires_grad=True)
# Epoch 921, 평균 비용: 0.017002562060952187, a: tensor([10.4599], requires_grad=True), b: tensor([-2.0027], requires_grad=True)
# Epoch 922, 평균 비용: 0.016972098499536514, a: tensor([10.4607], requires_grad=True), b: tensor([-2.0011], requires_grad=True)
# Epoch 923, 평균 비용: 0.01694176159799099, a: tensor([10.4614], requires_grad=True), b: tensor([-1.9995], requires_grad=True)
# Epoch 924, 평균 비용: 0.016911542043089867, a: tensor([10.4621], requires_grad=True), b: tensor([-1.9980], requires_grad=True)
# Epoch 925, 평균 비용: 0.01688140444457531, a: tensor([10.4628], requires_grad=True), b: tensor([-1.9964], requires_grad=True)
# Epoch 926, 평균 비용: 0.016851386055350304, a: tensor([10.4636], requires_grad=True), b: tensor([-1.9948], requires_grad=True)
# Epoch 927, 평균 비용: 0.01682147942483425, a: tensor([10.4643], requires_grad=True), b: tensor([-1.9932], requires_grad=True)
# Epoch 928, 평균 비용: 0.016791703179478645, a: tensor([10.4650], requires_grad=True), b: tensor([-1.9917], requires_grad=True)
# Epoch 929, 평균 비용: 0.016762010753154755, a: tensor([10.4658], requires_grad=True), b: tensor([-1.9901], requires_grad=True)
# Epoch 930, 평균 비용: 0.01673242077231407, a: tensor([10.4665], requires_grad=True), b: tensor([-1.9886], requires_grad=True)
# Epoch 931, 평균 비용: 0.016702957451343536, a: tensor([10.4672], requires_grad=True), b: tensor([-1.9870], requires_grad=True)
# Epoch 932, 평균 비용: 0.01667359285056591, a: tensor([10.4679], requires_grad=True), b: tensor([-1.9855], requires_grad=True)
# Epoch 933, 평균 비용: 0.016644328832626343, a: tensor([10.4687], requires_grad=True), b: tensor([-1.9839], requires_grad=True)
# Epoch 934, 평균 비용: 0.01661515049636364, a: tensor([10.4694], requires_grad=True), b: tensor([-1.9824], requires_grad=True)
# Epoch 935, 평균 비용: 0.01658608391880989, a: tensor([10.4701], requires_grad=True), b: tensor([-1.9808], requires_grad=True)
# Epoch 936, 평균 비용: 0.016557149589061737, a: tensor([10.4708], requires_grad=True), b: tensor([-1.9793], requires_grad=True)
# Epoch 937, 평균 비용: 0.01652829721570015, a: tensor([10.4715], requires_grad=True), b: tensor([-1.9777], requires_grad=True)
# Epoch 938, 평균 비용: 0.01649954356253147, a: tensor([10.4722], requires_grad=True), b: tensor([-1.9762], requires_grad=True)
# Epoch 939, 평균 비용: 0.016470903530716896, a: tensor([10.4730], requires_grad=True), b: tensor([-1.9747], requires_grad=True)
# Epoch 940, 평균 비용: 0.016442378982901573, a: tensor([10.4737], requires_grad=True), b: tensor([-1.9732], requires_grad=True)
# Epoch 941, 평균 비용: 0.016413940116763115, a: tensor([10.4744], requires_grad=True), b: tensor([-1.9716], requires_grad=True)
# Epoch 942, 평균 비용: 0.016385596245527267, a: tensor([10.4751], requires_grad=True), b: tensor([-1.9701], requires_grad=True)
# Epoch 943, 평균 비용: 0.01635732129216194, a: tensor([10.4758], requires_grad=True), b: tensor([-1.9686], requires_grad=True)
# Epoch 944, 평균 비용: 0.01632920652627945, a: tensor([10.4765], requires_grad=True), b: tensor([-1.9671], requires_grad=True)
# Epoch 945, 평균 비용: 0.01630116067826748, a: tensor([10.4772], requires_grad=True), b: tensor([-1.9655], requires_grad=True)
# Epoch 946, 평균 비용: 0.01627322845160961, a: tensor([10.4779], requires_grad=True), b: tensor([-1.9640], requires_grad=True)
# Epoch 947, 평균 비용: 0.01624537818133831, a: tensor([10.4786], requires_grad=True), b: tensor([-1.9625], requires_grad=True)
# Epoch 948, 평균 비용: 0.016217626631259918, a: tensor([10.4793], requires_grad=True), b: tensor([-1.9610], requires_grad=True)
# Epoch 949, 평균 비용: 0.01618999056518078, a: tensor([10.4800], requires_grad=True), b: tensor([-1.9595], requires_grad=True)
# Epoch 950, 평균 비용: 0.016162466257810593, a: tensor([10.4807], requires_grad=True), b: tensor([-1.9580], requires_grad=True)
# Epoch 951, 평균 비용: 0.016134964302182198, a: tensor([10.4814], requires_grad=True), b: tensor([-1.9565], requires_grad=True)
# Epoch 952, 평균 비용: 0.016107622534036636, a: tensor([10.4821], requires_grad=True), b: tensor([-1.9550], requires_grad=True)
# Epoch 953, 평균 비용: 0.01608031615614891, a: tensor([10.4828], requires_grad=True), b: tensor([-1.9535], requires_grad=True)
# Epoch 954, 평균 비용: 0.01605316996574402, a: tensor([10.4835], requires_grad=True), b: tensor([-1.9520], requires_grad=True)
# Epoch 955, 평균 비용: 0.016026105731725693, a: tensor([10.4842], requires_grad=True), b: tensor([-1.9505], requires_grad=True)
# Epoch 956, 평균 비용: 0.01599912717938423, a: tensor([10.4849], requires_grad=True), b: tensor([-1.9490], requires_grad=True)
# Epoch 957, 평균 비용: 0.015972228720784187, a: tensor([10.4856], requires_grad=True), b: tensor([-1.9476], requires_grad=True)
# Epoch 958, 평균 비용: 0.015945428982377052, a: tensor([10.4863], requires_grad=True), b: tensor([-1.9461], requires_grad=True)
# Epoch 959, 평균 비용: 0.01591874100267887, a: tensor([10.4870], requires_grad=True), b: tensor([-1.9446], requires_grad=True)
# Epoch 960, 평균 비용: 0.015892107039690018, a: tensor([10.4877], requires_grad=True), b: tensor([-1.9431], requires_grad=True)
# Epoch 961, 평균 비용: 0.015865569934248924, a: tensor([10.4884], requires_grad=True), b: tensor([-1.9417], requires_grad=True)
# Epoch 962, 평균 비용: 0.015839146450161934, a: tensor([10.4891], requires_grad=True), b: tensor([-1.9402], requires_grad=True)
# Epoch 963, 평균 비용: 0.015812821686267853, a: tensor([10.4897], requires_grad=True), b: tensor([-1.9387], requires_grad=True)
# Epoch 964, 평균 비용: 0.01578654535114765, a: tensor([10.4904], requires_grad=True), b: tensor([-1.9373], requires_grad=True)
# Epoch 965, 평균 비용: 0.015760401263833046, a: tensor([10.4911], requires_grad=True), b: tensor([-1.9358], requires_grad=True)
# Epoch 966, 평균 비용: 0.015734335407614708, a: tensor([10.4918], requires_grad=True), b: tensor([-1.9343], requires_grad=True)
# Epoch 967, 평균 비용: 0.015708371996879578, a: tensor([10.4925], requires_grad=True), b: tensor([-1.9329], requires_grad=True)
# Epoch 968, 평균 비용: 0.015682470053434372, a: tensor([10.4932], requires_grad=True), b: tensor([-1.9314], requires_grad=True)
# Epoch 969, 평균 비용: 0.015656670555472374, a: tensor([10.4938], requires_grad=True), b: tensor([-1.9300], requires_grad=True)
# Epoch 970, 평균 비용: 0.015630919486284256, a: tensor([10.4945], requires_grad=True), b: tensor([-1.9285], requires_grad=True)
# Epoch 971, 평균 비용: 0.015605282969772816, a: tensor([10.4952], requires_grad=True), b: tensor([-1.9271], requires_grad=True)
# Epoch 972, 평균 비용: 0.01557975821197033, a: tensor([10.4959], requires_grad=True), b: tensor([-1.9256], requires_grad=True)
# Epoch 973, 평균 비용: 0.015554284676909447, a: tensor([10.4965], requires_grad=True), b: tensor([-1.9242], requires_grad=True)
# Epoch 974, 평균 비용: 0.015528923831880093, a: tensor([10.4972], requires_grad=True), b: tensor([-1.9227], requires_grad=True)
# Epoch 975, 평균 비용: 0.01550364587455988, a: tensor([10.4979], requires_grad=True), b: tensor([-1.9213], requires_grad=True)
# Epoch 976, 평균 비용: 0.015478448010981083, a: tensor([10.4986], requires_grad=True), b: tensor([-1.9199], requires_grad=True)
# Epoch 977, 평균 비용: 0.015453318133950233, a: tensor([10.4992], requires_grad=True), b: tensor([-1.9184], requires_grad=True)
# Epoch 978, 평균 비용: 0.01542828418314457, a: tensor([10.4999], requires_grad=True), b: tensor([-1.9170], requires_grad=True)
# Epoch 979, 평균 비용: 0.015403319150209427, a: tensor([10.5006], requires_grad=True), b: tensor([-1.9156], requires_grad=True)
# Epoch 980, 평균 비용: 0.015378464013338089, a: tensor([10.5012], requires_grad=True), b: tensor([-1.9141], requires_grad=True)
# Epoch 981, 평균 비용: 0.01535366103053093, a: tensor([10.5019], requires_grad=True), b: tensor([-1.9127], requires_grad=True)
# Epoch 982, 평균 비용: 0.015328970737755299, a: tensor([10.5026], requires_grad=True), b: tensor([-1.9113], requires_grad=True)
# Epoch 983, 평균 비용: 0.01530434563755989, a: tensor([10.5032], requires_grad=True), b: tensor([-1.9099], requires_grad=True)
# Epoch 984, 평균 비용: 0.015279817394912243, a: tensor([10.5039], requires_grad=True), b: tensor([-1.9085], requires_grad=True)
# Epoch 985, 평균 비용: 0.015255341306328773, a: tensor([10.5046], requires_grad=True), b: tensor([-1.9070], requires_grad=True)
# Epoch 986, 평균 비용: 0.015230991877615452, a: tensor([10.5052], requires_grad=True), b: tensor([-1.9056], requires_grad=True)
# Epoch 987, 평균 비용: 0.015206693671643734, a: tensor([10.5059], requires_grad=True), b: tensor([-1.9042], requires_grad=True)
# Epoch 988, 평균 비용: 0.015182461589574814, a: tensor([10.5065], requires_grad=True), b: tensor([-1.9028], requires_grad=True)
# Epoch 989, 평균 비용: 0.015158326365053654, a: tensor([10.5072], requires_grad=True), b: tensor([-1.9014], requires_grad=True)
# Epoch 990, 평균 비용: 0.015134257264435291, a: tensor([10.5079], requires_grad=True), b: tensor([-1.9000], requires_grad=True)
# Epoch 991, 평균 비용: 0.015110284090042114, a: tensor([10.5085], requires_grad=True), b: tensor([-1.8986], requires_grad=True)
# Epoch 992, 평균 비용: 0.01508637797087431, a: tensor([10.5092], requires_grad=True), b: tensor([-1.8972], requires_grad=True)
# Epoch 993, 평균 비용: 0.015062536112964153, a: tensor([10.5098], requires_grad=True), b: tensor([-1.8958], requires_grad=True)
# Epoch 994, 평균 비용: 0.015038806945085526, a: tensor([10.5105], requires_grad=True), b: tensor([-1.8944], requires_grad=True)
# Epoch 995, 평균 비용: 0.015015160664916039, a: tensor([10.5111], requires_grad=True), b: tensor([-1.8930], requires_grad=True)
# Epoch 996, 평균 비용: 0.014991562813520432, a: tensor([10.5118], requires_grad=True), b: tensor([-1.8916], requires_grad=True)
# Epoch 997, 평균 비용: 0.014968063682317734, a: tensor([10.5124], requires_grad=True), b: tensor([-1.8903], requires_grad=True)
# Epoch 998, 평균 비용: 0.01494462788105011, a: tensor([10.5131], requires_grad=True), b: tensor([-1.8889], requires_grad=True)
# Epoch 999, 평균 비용: 0.014921274967491627, a: tensor([10.5137], requires_grad=True), b: tensor([-1.8875], requires_grad=True)

# %%
print(f"\n학습 완료 후의 최적값: a = {a}, b = {b}")
# Out:
# 학습 완료 후의 최적값: a = tensor([10.5137], requires_grad=True), b = tensor([-1.8875], requires_grad=True)

# %%
input_height = 185

input_norm = (input_height - X_mean) / X_std

z_input = a * input_norm + b

probability = sigmoid(z_input)

print(f"\n키가 {input_height}cm인 사람의 농구선수 확률: {probability}")

if probability >= 0.5:
    print("판별 결과: 농구선수입니다.")
else:
    print("판별 결과: 농구선수가 아닙니다.")
# Out:
# 키가 185cm인 사람의 농구선수 확률: tensor([0.9995], grad_fn=<MulBackward0>)
# 판별 결과: 농구선수입니다.
